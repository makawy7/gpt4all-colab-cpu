# %% [markdown]
# <a href="https://colab.research.google.com/github/makawy7/gpt4all-colab-cpu/blob/main/gpt4all_colab_cpu.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !git clone --recurse-submodules https://github.com/nomic-ai/gpt4all.git
# !git submodule configure && git submodule update

# Install the requirements in gpt4all directory
# !python -m pip install -r /content/gpt4all/requirements.txt

# Install the transformers and peft modules
# !pip install -e /content/gpt4all/transformers
# !pip install -e /content/gpt4all/peft

# Download the model and execute the binary
# %cd /content/gpt4all/chat
# !wget https://s3.amazonaws.com/static.nomic.ai/gpt4all/models/gpt4all-lora-quantized.bin
# !./gpt4all-lora-quantized-linux-x86
